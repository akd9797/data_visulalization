# %% [markdown]
# ###### IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # LOADING THE DATASET

# %%
df= pd.read_csv('hotel_bookings 2.csv')
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
df.tail(10)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119380             August                        35
# 119381             August                        35
# 119382             August                        35
# 119383             August                        35
# ...

# %%
df.shape
# Out:
# (119390, 32)

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df['reservation_status_date']=pd.to_datetime(df['reservation_status_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.describe(include='object')
# Out:
#              hotel arrival_date_month    meal country market_segment  \
# count       119390             119390  119390  118902         119390
# unique           2                 12       5     177              8
# top     City Hotel             August      BB     PRT      Online TA
# freq         79330              13877   92310   48590          56477
#
#        distribution_channel reserved_room_type assigned_room_type  \
# count                119390             119390             119390
# unique                    5                 10                 12
# top                   TA/TO                  A                  A
# freq                  97870              85994              74053
#
#        deposit_type customer_type reservation_status
# count        119390        119390             119390
# unique            3             4                  3
# top      No Deposit     Transient          Check-Out
# freq         104641         89613              75166

# %%
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %%
df.describe()
# Out:
#        is_canceled   lead_time  arrival_date_year  arrival_date_week_number  \
# count   217.000000  217.000000         217.000000                217.000000
# mean      0.078341   40.520737        2015.465438                 38.198157
# std       0.269329   61.748375           0.720053                 12.890292
# min       0.000000    0.000000        2015.000000                  1.000000
# 25%       0.000000   12.000000        2015.000000                 33.000000
# 50%       0.000000   27.000000        2015.000000                 45.000000
# 75%       0.000000   36.000000        2016.000000                 46.000000
# max       1.000000  364.000000        2017.000000                 53.000000
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count                 217.000000                217.00000
# mean                   10.824885                  1.56682
# std                     7.582065                  1.49270
# ...

# %%
df['adr'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df=df[df['adr']<153]

# %%
df.describe()
# Out:
#        is_canceled   lead_time  arrival_date_year  arrival_date_week_number  \
# count   209.000000  209.000000         209.000000                209.000000
# mean      0.081340   40.363636        2015.440191                 38.311005
# std       0.274012   61.705269           0.718915                 13.065071
# min       0.000000    0.000000        2015.000000                  1.000000
# 25%       0.000000   13.000000        2015.000000                 33.000000
# 50%       0.000000   28.000000        2015.000000                 45.000000
# 75%       0.000000   36.000000        2016.000000                 46.000000
# max       1.000000  364.000000        2017.000000                 53.000000
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count                 209.000000               209.000000
# mean                   10.703349                 1.588517
# std                     7.474832                 1.507374
# ...

# %%
df['lead_time'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df=df[df['lead_time']<105]

# %%
df.describe()
# Out:
#        is_canceled   lead_time  arrival_date_year  arrival_date_week_number  \
# count   192.000000  192.000000         192.000000                192.000000
# mean      0.083333   23.052083        2015.364583                 38.395833
# std       0.277108   13.653429           0.688268                 13.352239
# min       0.000000    0.000000        2015.000000                  1.000000
# 25%       0.000000   11.750000        2015.000000                 34.500000
# 50%       0.000000   24.000000        2015.000000                 45.000000
# 75%       0.000000   35.000000        2015.000000                 46.000000
# max       1.000000   70.000000        2017.000000                 53.000000
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count                 192.000000               192.000000
# mean                   10.312500                 1.578125
# std                     7.570005                 1.563370
# ...

# %%
cancelled=df['is_canceled'].value_counts()
cancelled
# Out:
# 0    176
# 1     16
# Name: is_canceled, dtype: int64

# %%
cancelled_perc=df['is_canceled'].value_counts(normalize=True)
cancelled_perc
# Out:
# 0    0.916667
# 1    0.083333
# Name: is_canceled, dtype: float64

# %%
plt.figure(figsize=(6,5))
plt.title('Reservation_status count',size=30)
plt.bar(['Not canceled','Canceled'],df['is_canceled'].value_counts())
plt.show()

# %%
plt.figure(figsize=(8,4))
ax1=sns.countplot(x='hotel',hue='is_canceled',data=df)
plt.title('Reservation status in differnt hotels',size=40)
plt.xlabel('hotel')
plt.ylabel('number of reservations')
plt.show()

# %%
resort_hotel= df[df['hotel']=='Resort Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.913043
# 1    0.086957
# Name: is_canceled, dtype: float64

# %%
cityt_hotel= df[df['hotel']=='city Hotel']
resort_hotel['is_canceled'].value_counts(normalize=True)
# Out:
# 0    0.913043
# 1    0.086957
# Name: is_canceled, dtype: float64

# %%
df['month']=df['reservation_status_date'].dt.month
plt.figure(figsize=(16,9))
ax1=sns.countplot(x='month',hue='is_canceled',data=df)
plt.title('Reservation status per month',size=30)
plt.xlabel('month')
plt.legend(['not canceled','canceled'])
plt.show()

# %%
cancelled_data = df[df['is_canceled']==1]
top_10_country = cancelled_data['country'].value_counts()
plt.figure(figsize = (10,10))
plt.title('Top 10 countries with reservation canceled')
plt.pie(top_10_country,autopct =' %.2f', labels = top_10_country.index)
plt.show()

# %%
df['market_segment'].value_counts()
# Out:
# Corporate        131
# Online TA         29
# Direct            16
# Offline TA/TO     14
# Complementary      2
# Name: market_segment, dtype: int64

# %%
df['market_segment'].value_counts(normalize= True)
# Out:
# Corporate        0.682292
# Online TA        0.151042
# Direct           0.083333
# Offline TA/TO    0.072917
# Complementary    0.010417
# Name: market_segment, dtype: float64

# %%
cancelled_data['market_segment'].value_counts(normalize=True)
# Out:
# Corporate    0.8125
# Direct       0.1250
# Online TA    0.0625
# Name: market_segment, dtype: float64

# %%
df['arrival_date_year'].value_counts()
# Out:
# 2015    145
# 2016     24
# 2017     23
# Name: arrival_date_year, dtype: int64

# %%
df['arrival_date_year'].value_counts(normalize=True)
# Out:
# 2015    0.755208
# 2016    0.125000
# 2017    0.119792
# Name: arrival_date_year, dtype: float64

# %%
df['arrival_date_month'].value_counts(normalize=True)
# Out:
# November     0.666667
# May          0.093750
# August       0.067708
# January      0.057292
# October      0.041667
# March        0.026042
# December     0.020833
# February     0.010417
# September    0.010417
# April        0.005208
# Name: arrival_date_month, dtype: float64

# %%
df['adults'].value_counts()
# Out:
# 1    128
# 2     63
# 3      1
# Name: adults, dtype: int64

# %%
df['days_in_waiting_list'].value_counts(normalize=True)
# Out:
# 0    1.0
# Name: days_in_waiting_list, dtype: float64

# %%
df['previous_bookings_not_canceled'].value_counts(normalize=True)
# Out:
# 0    0.927083
# 1    0.031250
# 2    0.026042
# 4    0.005208
# 5    0.005208
# 7    0.005208
# Name: previous_bookings_not_canceled, dtype: float64

# %%
df['year']=df['reservation_status_date'].dt.year
plt.figure(figsize=(16,9))
ax1=sns.countplot(x='year',hue='previous_bookings_not_canceled',data=df)
plt.title('previous_bookings_not_canceled,caneled',size=40)
plt.xlabel('year')
plt.legend(['not canceled','canceled'])
plt.show()

# %%
df['month']=df['reservation_status_date'].dt.month
plt.figure(figsize=(16,9))
ax1=sns.countplot(x='month',hue='previous_bookings_not_canceled',data=df)
plt.title('previous_bookings_not_canceled,canceled',size=40)
plt.xlabel('month')
plt.legend(['not canceled','canceled'])
plt.show()

# %%
plt.figure(figsize=(16,9))
ax1=sns.countplot(x='is_canceled',hue='adult',data=df)
plt.title('previous_bookings_not_canceled',size=40)
plt.xlabel('is_canceled')
plt.legend(['not canceled','canceled'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [161], in <cell line: 2>()
#       1 plt.figure(figsize=(16,9))
# ----> 2 ax1=sns.countplot(x='is_canceled',hue='adult',data=df)
#       3 plt.title('previous_bookings_not_canceled',size=40)
#       4 plt.xlabel('is_canceled')
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %% [markdown]
# # SUGGESTIONS

# %%
1  CANCELLATION RATES RISE AS THE PRICE DOES. IN ORDER TO PREVENT CANCELLATION OF RESERVATIONS, HOTELS COULD WORK 
   ON THEIR PRICING STRATEGIES AND TRY TO LOWER THE RATES FOR SPECIFIC HOTELS BASED ON LOCATION. THEY CAN ALSO
    PROVIDE SOME  DISCOUNTS TO THE CONSUMERS.
    
2  AS THE RATIO OF CANCELLATION AND NOT CANCELLATION OF THE RESORT HOTEL IS HIGHER IN THE RESORT THEN THE CITY HOTELS
   SHOULD PROVIDE A REASONABLE DISCOUNT ON THE ROOM PRICES ON WEEKENDS OR ON HOLIDAYS.

3 THEY CAN ALSO INCREASE THE QUALITY OF THEIR HOTELS AND THIRE SERVICES MAINLY IN PORTUGAL TO REDUCE THE CANCELLATION RATE.
