# %%
from bs4 import BeautifulSoup as bs

# %%
import requests

# %%
url="https://www.flipkart.com/realme-c35-glowing-green-64-gb/p/itmafb045222b2cf?pid=MOBGBTHFSKHF8RAU&lid=LSTMOBGBTHFSKHF8RAUQONXWY&marketplace=FLIPKART&q=realme+c35+mobile&store=tyy%2F4io&srno=s_1_2&otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&fm=organic&iid=ecc62d7e-e3b5-43d8-9b05-eb48dbd71bb8.MOBGBTHFSKHF8RAU.SEARCH&ppt=hp&ppn=homepage&ssid=aktrl42srk0000001676879692890&qH=eb8a5aaa14d24e12"

# %%
r=requests.get(url)
r
# Out:
# <Response [200]>

# %%
r.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e84a00.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
htmlcontent=r.content
htmlcontent
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e84a00.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
soup=bs(htmlcontent,"html.parser")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.e84a00.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# ...

# %% [markdown]
# # title of the product

# %%
title=soup.title
print(title)
# Out:
# <title>realme C35 ( 64 GB Storage, 4 GB RAM ) Online at Best Price On Flipkart.com</title>

# %% [markdown]
# # check the product price

# %%
price=soup.find_all("div",class_="_30jeq3 _16Jk6d")

# %%
price
# Out:
# [<div class="_30jeq3 _16Jk6d">₹11,999</div>]

# %%
product_price=[]
for i in range(0,len(price)):
    product_price.append(price[i].get_text())

# %%
product_price
# Out:
# ['₹11,999']

# %% [markdown]
# # get all the customar comments

# %%
 review=soup.find_all("p",class_="_2-N8zT")

# %%
review
# Out:
# [<p class="_2-N8zT">Excellent</p>,
#  <p class="_2-N8zT">Nice</p>,
#  <p class="_2-N8zT">Worth every penny</p>,
#  <p class="_2-N8zT">Awesome</p>,
#  <p class="_2-N8zT">Simply awesome</p>,
#  <p class="_2-N8zT">Wonderful</p>,
#  <p class="_2-N8zT">Classy product</p>,
#  <p class="_2-N8zT">Worth every penny</p>,
#  <p class="_2-N8zT">Brilliant</p>,
#  <p class="_2-N8zT">Great product</p>]

# %%
cust_rev=[]
for i in range(0,len(review)):
    cust_rev.append(review[i].get_text())

# %%
cust_rev
# Out:
# ['Excellent',
#  'Nice',
#  'Worth every penny',
#  'Awesome',
#  'Simply awesome',
#  'Wonderful',
#  'Classy product',
#  'Worth every penny',
#  'Brilliant',
#  'Great product']

# %% [markdown]
# # check how much star gives customars to this product

# %%
star=soup.find_all("div",class_="_3LWZlK _1BLPMq")

# %%
star
# Out:
# [<div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div>]

# %%
cust_star=[]

for i in range(0,len(star)):
    cust_star.append(star[i].get_text())

# %%
cust_star
# Out:
# ['5', '3', '5', '5', '5', '5', '5', '5', '5', '5']

# %% [markdown]
# # get all the customers review to this product

# %%
review = soup.find_all("div",class_="t-ZTKy")

# %%
review
# Out:
# [<div class="t-ZTKy"><div><div class="">I really like this phone . I am very happy. My family is very happy. When I received the mobile the package is very beautiful. I like the colour and model. Thank you flipkart.</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>,
#  <div class="t-ZTKy"><div><div class="">Wow so beautiful mobile i liket so really looking so beautiful i am so happy 🥰</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div>,
# ...

# %% [markdown]
# # Ratings & Reviews

# %%
all_=soup.find_all("div",class_=("row _3AjFsn _2c2kV-"))

# %%
all_
# Out:
# [<div class="row _3AjFsn _2c2kV-"><div class="_2e3Uck"><div class="row"><div class="col-4-12"><div class="col"><div class="row"><div class="col-12-12 _1azcI6"><div class="_2d4LTz">4.4</div><div class="_2yxeXv">★</div></div></div><div class="row _2afbiS"><div class="col-12-12"><span>1,68,453 Ratings &amp;</span></div></div><div class="row _2afbiS"><div class="col-12-12"><span>9,778 Reviews</span></div></div></div></div><div class="col-8-12 _3qpj74 _31DkEZ"><div class="_13sFCC miQW6D _2m9Pwo"><ul class="_2jr1F_"><li class="_28Xb_u"><div class="omG9iE"><span class="_26f_zl">5</span><span class="_2xBWPJ">★</span></div></li><li class="_28Xb_u"><div class="omG9iE"><span class="_26f_zl">4</span><span class="_2xBWPJ">★</span></div></li><li class="_28Xb_u"><div class="omG9iE"><span class="_26f_zl">3</span><span class="_2xBWPJ">★</span></div></li><li class="_28Xb_u"><div class="omG9iE"><span class="_26f_zl">2</span><span class="_2xBWPJ">★</span></div></li><li class="_28Xb_u"><div class="omG9iE
# ...

# %%
for image in soup.find_all('img'):
    print(image.get('src'))
# Out:
# //static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/flipkart-plus_8d85f4.png
# //static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/img/plus_aef861.png
# https://rukminim1.flixcart.com/image/128/128/l0fm07k0/mobile/y/g/i/-original-imagc7ryyhrrcgxh.jpeg?q=70
# https://rukminim1.flixcart.com/image/128/128/l0fm07k0/mobile/e/s/h/-original-imagc7ryavy8u769.jpeg?q=70
# https://rukminim1.flixcart.com/image/128/128/l0fm07k0/mobile/5/e/v/-original-imagc7ryyd8rmhwg.jpeg?q=70
# https://rukminim1.flixcart.com/image/128/128/l0fm07k0/mobile/w/x/o/-original-imagc7ryzqjas9gn.jpeg?q=70
# https://rukminim1.flixcart.com/image/128/128/l0fm07k0/mobile/y/e/t/-original-imagc7ryagxpd2uf.jpeg?q=70
# https://rukminim1.flixcart.com/image/128/128/l0fm07k0/mobile/q/c/y/-original-imagc7rycqqkbbut.jpeg?q=70
# https://rukminim1.flixcart.com/image/128/128/l0fm07k0/mobile/x/q/d/-original-imagc7ryzpnfngqr.jpeg?q=70
# ...

# %%
len(cust_star)
len(cust_rev)
# Out:
# 10

# %%
import pandas as pd

# %%
mobile = {
   " Review" : cust_rev,
    "Name": cust_star,
    "Product Price":price
}

# %%
df1 = pd.DataFrame(mobile)
# # df["Title"][0]=title
# df["Price"][0]=product_price
# df["Review"][1]=cust_rev
# df["Rating"][2]=all_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df1 = pd.DataFrame(mobile)
#
# NameError: name 'pd' is not defined

# %%
df1
# Out:
#               Review Name
# 0          Excellent    5
# 1               Nice    3
# 2  Worth every penny    5
# 3            Awesome    5
# 4     Simply awesome    5
# 5          Wonderful    5
# 6     Classy product    5
# 7  Worth every penny    5
# 8          Brilliant    5
# 9      Great product    5
